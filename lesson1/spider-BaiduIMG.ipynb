# %%
import requests
import os
import imghdr

# %%
def getMorePages(keyword, pages):
    params=[]
    for i in range(30, 30*pages+30, 30): #步长为30
        params.append({
            'tn': 'resultjson_com',
            'ipn': 'rj',
            'ct': '201326592',
            'is':'' ,
            'fp': 'result',
            'queryWord': keyword,
            'cl': 2,
            'lm': -1,
            'ie': 'utf-8',
            'oe': 'utf-8',
            'adpicid': '',
            'st': -1,
            'z': '',
            'ic': '',
            'hd': '',
            'latest': '',
            'copyright': '',
            'word': keyword,
            's': '',
            'se': '',
            'tab': '',
            'width': '',
            'height': '',
            'face': 0,
            'istype': 2,
            'qc': '',
            'nc': 1,
            'fr': '',
            'expermode': '',
            'force': '',
            'pn': i,
            'rn': 30,
            'gsm': '1e',})
    url = 'https://image.baidu.com/search/index'
    urls = []
    for i in params:
        res = requests.get(url, params=i)
        for item in res.json()['data'][:-1]:
            urls.append(item['thumbURL'])
    return urls

# %%
def writeImg(Path, urls):
    if not os.path.exists(Path): 
        os.mkdir(Path)
    i = 1;
    for u in urls:
        img = requests.get(u)
        with open(Path+'/'+str(i)+'.jpg', 'wb') as f:
            f.write(img.content)
            f.close()
        if imghdr.what(Path+'/'+str(i)+'.jpg')=='jpeg': #判断是否损坏
            print(str(i)+'.jpg is downloaded')
            i+=1

# %%
def crawl(Path, key, page=20):
    urls = getMorePages(key,page)
    writeImg(Path, urls)

# %%
crawl('data/schoolbus','编程')
# Out:
# 1.jpg is downloaded
# 2.jpg is downloaded
# 3.jpg is downloaded
# 4.jpg is downloaded
# 5.jpg is downloaded
# 6.jpg is downloaded
# 7.jpg is downloaded
# 8.jpg is downloaded
# 9.jpg is downloaded
# 10.jpg is downloaded
# 11.jpg is downloaded
# 12.jpg is downloaded
# 13.jpg is downloaded
# 14.jpg is downloaded
# 15.jpg is downloaded
# 16.jpg is downloaded
# 17.jpg is downloaded
# 18.jpg is downloaded
# 19.jpg is downloaded
# 20.jpg is downloaded
# 21.jpg is downloaded
# 22.jpg is downloaded
# 23.jpg is downloaded
# 24.jpg is downloaded
# 25.jpg is downloaded
# 26.jpg is downloaded
# 27.jpg is downloaded
# 28.jpg is downloaded
# 29.jpg is downloaded
# 30.jpg is downloaded
# 31.jpg is downloaded
# 32.jpg is downloaded
# 33.jpg is downloaded
# 34.jpg is downloaded
# 35.jpg is downloaded
# 36.jpg is downloaded
# 37.jpg is downloaded
# 38.jpg is downloaded
# 39.jpg is downloaded
# 40.jpg is downloaded
# 41.jpg is downloaded
# 42.jpg is downloaded
# 43.jpg is downloaded
# ...
